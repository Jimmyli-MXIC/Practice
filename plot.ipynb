# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
sns.set(style='darkgrid')
# %matplotlib notebook

# %%
tips = pd.read_table('/home/jimmyli/Downloads/机器学习实战/ch5/testSet.txt',sep='\s+', names = ['x', 'y', 'label'])

# %%
sns.lmplot(x='x', y='y',data=tips)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
min_imgs = pd.read_table('/home/jimmyli/Desktop/min_imgs.txt', sep='\t', names=['nrof_train_images', 'accuracy'])
min_imgs
# Out:
#    nrof_train_images  accuracy
# 0                  1     0.000
# 1                  2     0.197
# 2                  3     0.519
# 3                  4     0.859
# 4                  5     0.716
# 5                  6     0.900
# 6                  7     0.906
# 7                  8     0.918
# 8                  9     0.921
# 9                 10     0.923

# %%
sns.catplot(x="nrof_train_images", y="accuracy",kind="bar", palette="ch:.25", data=min_imgs)
#14个类别 622张图片
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.catplot(x="accuracy", y="nrof_train_images",
           markers=["o"], linestyles=["-"],
            kind="point", data=min_imgs);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
min_lfw = pd.read_table('/home/jimmyli/Desktop/min_lfw.txt', sep='\t', names=['nrof_classes', 'nrof_images', 'accuracy'],)
                       #ndex_col='nrof_classes')
min_lfw
# Out:
#    nrof_classes  nrof_images  accuracy
# 0            19         1772     1.000
# 1            62         2713     0.996
# 2           158         3534     0.989
# 3           311         3870     0.984

# %%
sns.catplot(x="nrof_classes", y="accuracy",kind="bar",
            hue="nrof_images", data=min_lfw)
# Out:
# <img src="data:image/png;base64,..." width="588.8">
